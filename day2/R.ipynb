# %%
message <-c(90,60,80,20,30)
print("dataset:")
print(message)
mean_value <- mean(message)
print(paste("Mean =",mean_value))
median_value <- median(message)
print(paste("Median =",median_value))
mode_function <- function(x){
    uniq_values <- unique(x)
    uniq_values[which.max(tabulate(match(x,uniq_values)))]
}
mode_value <- mode_function(message)
print(paste("Mode =",mode_value))
max_value <- max(message)
print(paste("Maximum =",max_value))
min_value <- min(message)
print(paste("Minimum =",min_value))
variance_value <- var(message)
print(paste("variance =",variance_value))
sd_value <- sd(message)
print(paste("standard deviation =",sd_value))
summary(message)
barplot(message)
hist(message)
boxplot(message)
plot(message)
# Out:
# [1] "dataset:"
# [1] 90 60 80 20 30
# [1] "Mean = 56"
# [1] "Median = 60"
# [1] "Mode = 90"
# [1] "Maximum = 90"
# [1] "Minimum = 20"
# [1] "variance = 930"
# [1] "standard deviation = 30.4959013639538"
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#      20      30      60      56      80      90
# plot without title
# Plot with title “Histogram of message”
# plot without title
# plot without title
