# %%
import statistics
import matplotlib.pyplot as plt
member_names=["mani","reddy","rohith","lakshmikar","charan"]
ages=[22,21,33,45,62]
workout_hours=[2,1.5,2.5,1,4]
calories_burned=[500,350,600,200,300]
print("fitness center dataset")
for i in range(len(member_names)):
  print(member_names[i],ages[i],workout_hours[i],calories_burned[i])
average_workout=sum(workout_hours)/len(workout_hours)
print("average workout hours:",average_workout)
biggest_calories=max(calories_burned)
print("biggest calories burned:",biggest_calories)
smallest_calories=min(calories_burned)
print("smallest calories burned:",smallest_calories)
median_calories=statistics.median(calories_burned)
print("median calories burned:",median_calories)
std_dev=statistics.stdev(calories_burned)
print("standard deviation",std_dev)
index=calories_burned.index(biggest_calories)
print("most active member=",member_names[index])
plt.bar(member_names,calories_burned)
plt.xlabel("members")
plt.ylabel("calories burned")
plt.title("fitness analysis")
plt.show()
plt.scatter(member_names,calories_burned)
plt.xlabel("members")
plt.ylabel("calories burned")
plt.title("fitness analysis")
plt.show()
# Out:
# fitness center dataset
# mani 22 2 500
# reddy 21 1.5 350
# rohith 33 2.5 600
# lakshmikar 45 1 200
# charan 62 4 300
# average workout hours: 2.2
# biggest calories burned: 600
# smallest calories burned: 200
# median calories burned: 350
# standard deviation 159.68719422671313
# most active member= rohith
